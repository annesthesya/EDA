# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
import re
import emoji
from num2words import num2words
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report
nltk.download('stopwords')
nltk.download('wordnet')
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from collections import Counter
from matplotlib import colors
from wordcloud import WordCloud
import docx 
from scipy.sparse import hstack, csr_matrix
from ipynb.fs.full.preprocessor_class import Preprocessor
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf 

from tensorflow.keras.optimizers import SGD, Adam
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Stefi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Stefi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
train_data = pd.read_csv('data/shuffled_train_data.csv',index_col=None)
train_labels = pd.read_csv('data/shuffled_train_labels.csv',index_col=None)

test_data = pd.read_csv('data/test_data.csv',index_col=None)
test_labels = pd.read_csv('data/test_labels.csv',index_col=None)

val_data = pd.read_csv('data/validation_data.csv',index_col=None)
val_labels = pd.read_csv('data/validation_labels.csv',index_col=None)

train_data.shape
# Out:
# (45000, 1)

# %%
preprocessor = Preprocessor(set(stopwords.words('english')), WordNetLemmatizer(), PorterStemmer(), True, True, True, True, True, False, True, True, True, False)

preprocessed_train_data = pd.DataFrame(columns=['text'])
preprocessed_test_data = pd.DataFrame(columns=['text'])
preprocessed_val_data = pd.DataFrame(columns=['text'])

preprocessed_train_data['text'] = train_data.apply(lambda row: preprocessor.preprocess(row.iloc[0]), axis = 1)
preprocessed_test_data['text'] = test_data.apply(lambda row: preprocessor.preprocess(row.iloc[0]), axis = 1)
preprocessed_val_data['text'] = val_data.apply(lambda row: preprocessor.preprocess(row.iloc[0]), axis = 1)

# %%
def proceseaza_texte_si_returneaza_lungime(text):    
    return len(text)

length_train_data = pd.DataFrame(columns=['text'])
length_test_data = pd.DataFrame(columns=['text'])
length_val_data = pd.DataFrame(columns=['text'])

length_train_data['text'] = train_data.apply(lambda row: proceseaza_texte_si_returneaza_lungime(row.iloc[0]), axis = 1)
length_test_data['text'] = test_data.apply(lambda row: proceseaza_texte_si_returneaza_lungime(row.iloc[0]), axis = 1)
length_val_data['text'] = val_data.apply(lambda row: proceseaza_texte_si_returneaza_lungime(row.iloc[0]), axis = 1)

# %%
preprocessed_train_data["text"] = preprocessed_train_data["text"].apply(lambda x: ",".join(x) if isinstance(x, list) else x)
print(preprocessed_train_data["text"])

preprocessed_test_data["text"] = preprocessed_test_data["text"].apply(lambda x: ",".join(x) if isinstance(x, list) else x)
print(preprocessed_test_data["text"])

preprocessed_val_data["text"] = preprocessed_val_data["text"].apply(lambda x: ",".join(x) if isinstance(x, list) else x)
print(preprocessed_val_data["text"])
# Out:
# 0                      want,something,cheap,give,away,last
# 1        look,cute,outside,wore,twice,vega,issue,year,l...
# 2        think,sending,back,zipper,stick,one,already,co...
# 3        usually,wear,birkenstock,made,woman,guess,made...
# 4        excited,today,arrived,home,package,door,opened...
#                                ...
# 44995       worn,bali,bra,year,last,comfortable,good,price
# 44996                soft,cool,beautiful,color,little,snug
# 44997    product,look,exactly,like,picture,impressed,du...
# 44998    granddaughter,age,loved,getting,birthstone,rin...
# 44999    good,versatile,athletic,underwear,lightweight,...
# Name: text, Length: 45000, dtype: object
# 0       shoe,simply,hurt,foot,sorry,already,worn,other...
# 1       run,small,fit,size,range,claim,least,case,retu...
# 2       almost,year,old,wear,size,brand,however,tank,f...
# 3       huge,heavy,shoe,felt,like,giant,hunk,plastic,f...
# 4       lost,flower,one,nd,week,wear,still,wear,though...
# ...

# %% [markdown]
# Logistic regression

# %%
tfidf = TfidfVectorizer(max_features=3000, ngram_range = (1, 3))

X_train_tfidf = tfidf.fit_transform(preprocessed_train_data["text"]).toarray()
X_test_tfidf = tfidf.transform(preprocessed_test_data["text"]).toarray()

length_train_data_numpy = preprocessed_train_data["text"].apply(lambda x: len(x.split())).values
length_test_data_numpy = preprocessed_test_data["text"].apply(lambda x: len(x.split())).values

length_train_data_sparse = csr_matrix(length_train_data_numpy.reshape(-1, 1))
length_test_data_sparse = csr_matrix(length_test_data_numpy.reshape(-1, 1))

X_train_combined = hstack([X_train_tfidf, length_train_data_sparse])
X_test_combined = hstack([X_test_tfidf, length_test_data_sparse])
model = LogisticRegression(solver="lbfgs", tol=3, C=0.3)

model.fit(X_train_combined, train_labels['0'])
predictions = model.predict(X_test_combined)

# %%
accuracy = accuracy_score(test_labels['label'], predictions)
from sklearn.metrics import classification_report

print("Accuracy:", accuracy)
print(classification_report(test_labels['label'], predictions))
# Out:
# Accuracy: 0.6938333333333333
#               precision    recall  f1-score   support
#
#     negative       0.68      0.80      0.74      2250
#      neutral       0.53      0.32      0.40      1500
#     positive       0.77      0.83      0.80      2250
#
#     accuracy                           0.69      6000
#    macro avg       0.66      0.65      0.65      6000
# weighted avg       0.68      0.69      0.68      6000

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(test_labels['label'], predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples', xticklabels = ['negative', 'neutral', 'positive'], yticklabels = ['negative', 'neutral', 'positive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# KNN

# %%
tfidf = TfidfVectorizer(max_features=5000, ngram_range = (1, 2))

X_train_tfidf = tfidf.fit_transform(preprocessed_train_data["text"]).toarray()
X_test_tfidf = tfidf.transform(preprocessed_test_data["text"]).toarray()

length_train_data_numpy = preprocessed_train_data["text"].apply(lambda x: len(x.split())).values
length_test_data_numpy = preprocessed_test_data["text"].apply(lambda x: len(x.split())).values

length_train_data_sparse = csr_matrix(length_train_data_numpy.reshape(-1, 1))
length_test_data_sparse = csr_matrix(length_test_data_numpy.reshape(-1, 1))

X_train_combined = hstack([X_train_tfidf, length_train_data_sparse])
X_test_combined = hstack([X_test_tfidf, length_test_data_sparse])
model = KNeighborsClassifier(n_neighbors = 9, weights = "uniform", metric = "cosine")

model.fit(X_train_combined, train_labels['0'])
predictions = model.predict(X_test_combined)

# %%
accuracy = accuracy_score(test_labels['label'], predictions)
from sklearn.metrics import classification_report

print("Accuracy:", accuracy)
print(classification_report(test_labels['label'], predictions))
# Out:
# Accuracy: 0.4856666666666667
#               precision    recall  f1-score   support
#
#     negative       0.52      0.51      0.51      2250
#      neutral       0.34      0.09      0.14      1500
#     positive       0.48      0.73      0.58      2250
#
#     accuracy                           0.49      6000
#    macro avg       0.45      0.44      0.41      6000
# weighted avg       0.46      0.49      0.45      6000

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(test_labels['label'], predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples', xticklabels = ['negative', 'neutral', 'positive'], yticklabels = ['negative', 'neutral', 'positive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# RFC

# %%
tfidf = TfidfVectorizer(max_features=3000, ngram_range = (1, 2))

X_train_tfidf = tfidf.fit_transform(preprocessed_train_data["text"]).toarray()
X_test_tfidf = tfidf.transform(preprocessed_test_data["text"]).toarray()

length_train_data_numpy = preprocessed_train_data["text"].apply(lambda x: len(x.split())).values
length_test_data_numpy = preprocessed_test_data["text"].apply(lambda x: len(x.split())).values

length_train_data_sparse = csr_matrix(length_train_data_numpy.reshape(-1, 1))
length_test_data_sparse = csr_matrix(length_test_data_numpy.reshape(-1, 1))

X_train_combined = hstack([X_train_tfidf, length_train_data_sparse])
X_test_combined = hstack([X_test_tfidf, length_test_data_sparse])
model = RandomForestClassifier()

model.fit(X_train_combined, train_labels['0'])
predictions = model.predict(X_test_combined)

# %%
accuracy = accuracy_score(test_labels['label'], predictions)
from sklearn.metrics import classification_report

print("Accuracy:", accuracy)
print(classification_report(test_labels['label'], predictions))
# Out:
# Accuracy: 0.666
#               precision    recall  f1-score   support
#
#     negative       0.65      0.81      0.72      2250
#      neutral       0.52      0.21      0.30      1500
#     positive       0.71      0.83      0.77      2250
#
#     accuracy                           0.67      6000
#    macro avg       0.63      0.61      0.60      6000
# weighted avg       0.64      0.67      0.63      6000

# %%
print(classification_report(test_labels['label'], predictions))
import seaborn as sns
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(test_labels['label'], predictions)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples', xticklabels=['negative', 'neutral', 'positive'],
            yticklabels=['negative', 'neutral', 'positive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.65      0.81      0.72      2250
#      neutral       0.52      0.21      0.30      1500
#     positive       0.71      0.83      0.77      2250
#
#     accuracy                           0.67      6000
#    macro avg       0.63      0.61      0.60      6000
# weighted avg       0.64      0.67      0.63      6000

# %% [markdown]
# NN

# %%
list_labels = []
for el in train_labels['0']:
    if el == 'positive':
        list_labels.append(2)
    if el == 'negative':
        list_labels.append(0)
    if el == 'neutral':
        list_labels.append(1)
        
list_test = []
for el in test_labels['label']:
    if el == 'positive':
        list_test.append(2)
    if el == 'negative':
        list_test.append(0)
    if el == 'neutral':
        list_test.append(1)
        
        
list_val = []
for el in val_labels['label']:
    if el == 'positive':
        list_val.append(2)
    if el == 'negative':
        list_val.append(0)
    if el == 'neutral':
        list_val.append(1)

# %%
def sort_sparse_indices(matrix):
    co = matrix.tocoo()
    sorted_indices = np.lexsort((co.col, co.row))
    return tf.sparse.reorder(tf.sparse.SparseTensor(
        indices = np.column_stack((co.row[sorted_indices], co.col[sorted_indices])),
        values = co.data[sorted_indices],
        dense_shape = co.shape
    ))

# %%
for max_ft in [5000]:
    for ngram_range in [(1, 3)]: 
        for layers_no in [1]:
            for units_no in [64]:
                for learning_rate in [0.0001]:
                    tfidf_vectorizer = TfidfVectorizer(ngram_range = ngram_range, max_features = max_ft)
                    train_tfidf = tfidf_vectorizer.fit_transform(preprocessed_train_data['text']) 
                    test_tfidf = tfidf_vectorizer.transform(preprocessed_test_data['text'])
                    val_tfidf = tfidf_vectorizer.transform(preprocessed_val_data['text'])
                    
                    length_train_data_numpy = preprocessed_train_data["text"].apply(lambda x: len(x.split())).values
                    length_test_data_numpy = preprocessed_test_data["text"].apply(lambda x: len(x.split())).values
                    length_val_data_numpy = preprocessed_val_data["text"].apply(lambda x: len(x.split())).values

                    length_train_data_sparse = csr_matrix(length_train_data_numpy.reshape(-1, 1))
                    length_test_data_sparse = csr_matrix(length_test_data_numpy.reshape(-1, 1))
                    length_val_data_sparse = csr_matrix(length_val_data_numpy.reshape(-1, 1))

                    X_train_combined = hstack([train_tfidf, length_train_data_sparse])
                    X_test_combined = hstack([test_tfidf, length_test_data_sparse])
                    X_val_combined = hstack([val_tfidf, length_val_data_sparse])

                    build_model = [tf.keras.layers.Input(shape=(5001,), sparse=True)]
                    for i in range(0, layers_no):
                        build_model.append(tf.keras.layers.Dense(units_no, activation='relu'))
                        build_model.append(tf.keras.layers.Dropout(0.3))
                    build_model.append(tf.keras.layers.Dense(3, activation='softmax'))
                    model = tf.keras.models.Sequential(build_model)

                    optimizer = Adam(learning_rate=learning_rate)  
                    model.compile(optimizer=optimizer,
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

                    X_train_combined_sorted = sort_sparse_indices(X_train_combined)

                    model.fit(X_train_combined_sorted, np.array(list_labels),
                    epochs=7, batch_size=32, initial_epoch=0,
                    validation_data=(sort_sparse_indices(X_val_combined), np.array(list_val)))

                    test_loss, test_metrics = model.evaluate(sort_sparse_indices(X_test_combined), np.array(list_test), verbose=0)
                    print('\n ngram_range -', ngram_range, 'max_ft -', max_ft, 'layers_no -', layers_no, 'units_no -', units_no, 'learning_rate -', learning_rate, '- LOSS -', test_loss, ' ACCURACY -', test_metrics)

                    
                    test_predictions = model.predict(sort_sparse_indices(X_test_combined))
                    predicted_labels = np.argmax(test_predictions, axis = 1)
                    
                    print(classification_report(np.array(list_test), predicted_labels))
                    conf_matrix = confusion_matrix(np.array(list_test), predicted_labels)
                    
                    plt.figure(figsize = (8, 6))
                    sns.heatmap(conf_matrix, annot = True, fmt = "d", cmap = "Purples", xticklabels = ['negative','neutral', 'positive'], yticklabels = ['negative', 'neutral', 'positive'])
                    plt.xlabel('Predicted Labels')
                    plt.ylabel('True Labels')
                    plt.title('Confusion Matrix')
                    plt.show()
                    print("-----------------------------------------------------------------------------------")
# Out:
# Epoch 1/7
# C:\Users\Stefi\PycharmProjects\PMLKaggle\venv\lib\site-packages\tensorflow\python\framework\indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential_12/dense_24/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential_12/dense_24/embedding_lookup_sparse/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/sequential_12/dense_24/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 1407/1407 [==============================] - 9s 5ms/step - loss: 0.9997 - accuracy: 0.5912 - val_loss: 0.8790 - val_accuracy: 0.6706
# Epoch 2/7
# 1407/1407 [==============================] - 9s 6ms/step - loss: 0.8049 - accuracy: 0.6688 - val_loss: 0.7447 - val_accuracy: 0.6915
# Epoch 3/7
# ...
